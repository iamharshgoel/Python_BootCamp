# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline

# %%
#Fetching the data of various Bnaks for the Project
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
BAC = data.DataReader('BAC','yahoo',start,end)

# %%
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.523922
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  35.146645
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  35.191933
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  35.139107
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  35.161732
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  16.071533
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.941246
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  16.080839
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.866797
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  15.662066
#
# [2517 rows x 6 columns]

# %%
# CitiGroup
C = data.DataReader('C','yahoo',start,end)
# Goldman Sachs
GS = data.DataReader('GS','yahoo',start,end)
# JPMorgan Chase
JPM = data.DataReader('JPM','yahoo',start,end)
#Morgan Stanley
MS = data.DataReader('GS','yahoo',start,end)
# Wells Fargo
WFC = data.DataReader('WFC','yahoo',start,end)

# %%
C
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994   1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988   1870900.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012   1143100.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012   1370200.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994   1680700.0
# ...                ...         ...         ...         ...         ...
# 2015-12-24   52.970001   52.450001   52.480000   52.709999   4671200.0
# 2015-12-28   52.570000   51.959999   52.570000   52.380001   8761700.0
# 2015-12-29   53.220001   52.740002   52.759998   52.980000  10155100.0
# 2015-12-30   52.939999   52.250000   52.840000   52.299999   8763300.0
# 2015-12-31   52.389999   51.750000   52.070000   51.750000  11281800.0
#
#              Adj Close
# Date
# 2006-01-03  445.561951
# 2006-01-04  437.335999
# 2006-01-05  439.505585
# ...

# %%
GS
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  129.440002  124.230003  126.699997  128.869995  6188700.0
# 2006-01-04  128.910004  126.379997  127.349998  127.089996  4861600.0
# 2006-01-05  127.320000  125.610001  126.000000  127.040001  3717400.0
# 2006-01-06  129.250000  127.290001  127.290001  128.839996  4319600.0
# 2006-01-09  130.619995  128.000000  128.500000  130.389999  4723500.0
# ...                ...         ...         ...         ...        ...
# 2015-12-24  183.169998  182.020004  182.270004  182.470001  1107600.0
# 2015-12-28  181.929993  179.839996  181.770004  181.619995  1723300.0
# 2015-12-29  184.179993  182.500000  182.820007  183.529999  1848900.0
# 2015-12-30  183.529999  181.839996  183.279999  182.009995  1514300.0
# 2015-12-31  182.889999  180.029999  181.160004  180.229996  1773900.0
#
#              Adj Close
# Date
# 2006-01-03  108.233147
# 2006-01-04  106.738167
# 2006-01-05  106.696220
# ...

# %%
JPM
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  40.360001  39.299999  39.830002  40.189999  12838600.0  27.815792
# 2006-01-04  40.139999  39.419998  39.779999  39.619999  13491500.0  27.655237
# 2006-01-05  39.810001  39.500000  39.610001  39.740002   8109400.0  27.738998
# 2006-01-06  40.240002  39.549999  39.919998  40.020000   7966900.0  27.934450
# 2006-01-09  40.720001  39.880001  39.880001  40.669998  16575200.0  28.388159
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  66.889999  66.320000  66.620003  66.599998   4468200.0  59.236908
# 2015-12-28  66.449997  65.709999  66.290001  66.379997   6610600.0  59.041222
# 2015-12-29  67.300003  66.739998  66.839996  67.070000   9820800.0  59.654938
# 2015-12-30  67.050003  66.449997  67.040001  66.589996   7190700.0  59.227997
# 2015-12-31  66.779999  66.000000  66.190002  66.029999  14654300.0  58.729919
#
# [2517 rows x 6 columns]

# %%
MS
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  129.440002  124.230003  126.699997  128.869995  6188700.0
# 2006-01-04  128.910004  126.379997  127.349998  127.089996  4861600.0
# 2006-01-05  127.320000  125.610001  126.000000  127.040001  3717400.0
# 2006-01-06  129.250000  127.290001  127.290001  128.839996  4319600.0
# 2006-01-09  130.619995  128.000000  128.500000  130.389999  4723500.0
# ...                ...         ...         ...         ...        ...
# 2015-12-24  183.169998  182.020004  182.270004  182.470001  1107600.0
# 2015-12-28  181.929993  179.839996  181.770004  181.619995  1723300.0
# 2015-12-29  184.179993  182.500000  182.820007  183.529999  1848900.0
# 2015-12-30  183.529999  181.839996  183.279999  182.009995  1514300.0
# 2015-12-31  182.889999  180.029999  181.160004  180.229996  1773900.0
#
#              Adj Close
# Date
# 2006-01-03  108.233147
# 2006-01-04  106.738167
# 2006-01-05  106.696220
# ...

# %%
WFC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  31.975000  31.195000  31.600000  31.900000  11016400.0  20.823185
# 2006-01-04  31.820000  31.365000  31.799999  31.530001  10870000.0  20.581659
# 2006-01-05  31.555000  31.309999  31.500000  31.495001  10158000.0  20.558811
# 2006-01-06  31.775000  31.385000  31.580000  31.680000   8403800.0  20.679575
# 2006-01-09  31.825001  31.555000  31.674999  31.674999   5619600.0  20.676311
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  55.090000  54.709999  54.970001  54.820000   4999400.0  47.736015
# 2015-12-28  54.779999  54.169998  54.549999  54.680000   8288800.0  47.614105
# 2015-12-29  55.349998  54.990002  55.110001  55.290001   7894900.0  48.145275
# 2015-12-30  55.310001  54.790001  55.270000  54.889999   8016900.0  47.796970
# 2015-12-31  54.950001  54.220001  54.509998  54.360001  10929800.0  47.335461
#
# [2517 rows x 6 columns]

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.523922
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  35.146645
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  35.191933
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  35.139107
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  35.161732
#
#                      C                                      ...          MS  \
#                   High         Low        Open       Close  ...        Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  126.699997
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  127.349998
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker', 'Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.523922  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   35.146645  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   35.191933  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 247.9199981689453
# WFC 58.52000045776367

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS     247.919998
# WFC     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183  -0.013812   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029  -0.000393   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.014169    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.012030   -0.000158

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2009-01-20
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-11-24
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.025390
# WFC Return    0.030238
# dtype: float64

# %%
returns.ix['2015-01-01':'2015-12-31'].std()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.014046
# WFC Return    0.012591
# dtype: float64

# %%
 sns.distplot(returns.ix['2015-01-01':'2015-12-31']['MS Return'],color='green')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
 sns.distplot(returns.ix['2008-01-01':'2008-12-31']['C Return'],color='green')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="ff9dd636-472a-4a56-a83a-0f06e8597a14" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ff9dd636-472a-4a56-a83a-0f06e8597a14")) {
#                     Plotly.newPlot(
#                         'ff9dd636-472a-4a56-a83a-0f06e8597a14',
# ...

# %%
BAC['Close'].ix['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Mov Avg')
BAC['Close'].ix['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
data = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()

# %%
sns.heatmap(data=data,annot=True)

# %%
close_corr = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()

# %%
close_corr.iplot(kind='heatmap')
# Out:
# <div>
#
#
#             <div id="0616c33a-aa8c-4266-866c-8925368678e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0616c33a-aa8c-4266-866c-8925368678e5")) {
#                     Plotly.newPlot(
#                         '0616c33a-aa8c-4266-866c-8925368678e5',
# ...

# %%
BAC[['Open','High','Low','Close']].ix['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="ec5e6d99-2e6f-416a-a8f9-5e2dcc8ea217" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ec5e6d99-2e6f-416a-a8f9-5e2dcc8ea217")) {
#                     Plotly.newPlot(
#                         'ec5e6d99-2e6f-416a-a8f9-5e2dcc8ea217',
# ...

# %%
MS['Close'].ix['2015-01-01':'2015-12-31'].ta_plot(study='sma',periods=[13,21,25])
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="d41dc85e-9149-4ad2-ad9e-72e8533196c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d41dc85e-9149-4ad2-ad9e-72e8533196c8")) {
#                     Plotly.newPlot(
#                         'd41dc85e-9149-4ad2-ad9e-72e8533196c8',
# ...

# %%
BAC['Close'].ix['2015-01-01':'2015-12-31'].ta_plot(study='boll')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="25d2ab14-12a5-46b7-986d-7228e8951493" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("25d2ab14-12a5-46b7-986d-7228e8951493")) {
#                     Plotly.newPlot(
#                         '25d2ab14-12a5-46b7-986d-7228e8951493',
# ...
